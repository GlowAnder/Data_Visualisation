# %%
import matplotlib.pyplot as plt

# %%
x=[0,2,4,6,8]
y=[0,4,16,36,64]

fig,ax=plt.subplots()
ax.plot(x,y,marker='x',label='pattern')

ax.legend(['lines'])

# %%
friend_name=['Kelvin','Diana','Gloria','Issah']

age=[20,18,16,14]

plt.bar(friend_name,age)

plt.title('FRIENDS AND THEIR AGES')

plt.xlabel('==N A M E S==')

plt.ylabel('==AGES==')

plt.show()

# %%
cars=['AUDI','BMW','FORD','TESLA','JAGUAR','MERCEDES']

data=
